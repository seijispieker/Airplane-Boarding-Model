# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
source_data = pd.read_csv("plot_data_source.csv")

source_data["people"] = source_data["x"].round(0)
source_data["boarding time"] = source_data["y"].round(2) 
sns.regplot(data = source_data, x = "people", y="boarding time", marker= "+")
plt.plot([0, 200], [0,20], color="black", linestyle= "--")
plt.xlim(0,200)
plt.ylim(0,20)
plt.show()

source_data.to_csv("scatter_soure.csv")
